# %% [markdown]
# Explicação Aula Sexta

# %%
a = 1

print(a)
# Out:
# 1

# %% [markdown]
# **Exercicio: Variaveis**

# %%
x = 25
y = 25

resultado = x + y

print('Resultado total: ',resultado)
# Out:
# Resultado total:  50

# %% [markdown]
# **Exercicio Calculadora**

# %%
calculo = input("Digite um caculo: ")

eval(calculo)
# Out:
# Digite um caculo: 9*6
# 54

# %%
# Calculadora simples usando eval() e input()defcalculadora():
eval(input("Informe o cálculo matemático: "))
# Out:
# Informe o cálculo matemático: 2+23
# 25

# %% [markdown]
# Strings em Python
