# %% [markdown]
# **Pyhton em Análise de Dados**

# %%
import pandas as pd

# %% [markdown]
# Dados de financeiros

# %%
money_data_frame = pd.read_csv("https://drive.google.com/uc?id=1FtG5iX48UGSi7V8CTf_luw7T8GCsu8kI")
money_data_frame.head()
# Out:
#      Country        GDP
# 0  Australia  50961.865
# 1    Austria  43724.031
# 2    Belgium  40106.632
# 3     Belize   4841.735
# 4    Bolivia   2886.231

# %% [markdown]
# Quanto as pessoas são felizes?!

# %%
happiness_data_frame = pd.read_csv("https://drive.google.com/uc?id=1A4PzcQLIM6i2JSmp3WPAbEDUaxMAfMJf")
happiness_data_frame.head(40)
# Out:
#             Country  Happiness
# 0         Australia        7.5
# 1           Austria        7.6
# 2           Belgium        7.3
# 3            Brazil        6.6
# 4            Canada        7.6
# 5             Chile        5.7
# 6          Colombia        6.3
# 7    Czech Republic        6.7
# 8           Denmark        7.9
# 9           Estonia        5.4
# 10          Finland        7.2
# 11           France        5.9
# 12          Germany        7.4
# 13           Greece        4.4
# 14          Hungary        5.1
# 15          Iceland        7.4
# 16          Ireland        7.2
# 17           Israel        7.4
# 18            Italy        5.7
# 19            Japan        6.0
# 20            Korea        6.1
# 21           Latvia        5.4
# 22        Lithuania        5.6
# 23       Luxembourg        6.8
# 24           Mexico        6.5
# 25      Netherlands        7.7
# 26      New Zealand        7.4
# 27           Norway        7.5
# 28           Poland        6.2
# ...

# %%
money_happiness_df = pd.merge(happiness_data_frame, money_data_frame,
                              on='Country')

# %%
money_happiness_df.head(40)
# Out:
#             Country  Happiness         GDP
# 0         Australia        7.5   50961.865
# 1           Austria        7.6   43724.031
# 2           Belgium        7.3   40106.632
# 3            Brazil        6.6    8669.998
# 4            Canada        7.6   43331.961
# 5             Chile        5.7   13340.905
# 6          Colombia        6.3    6083.510
# 7    Czech Republic        6.7   17256.918
# 8           Denmark        7.9   52114.165
# 9           Estonia        5.4   17288.083
# 10          Finland        7.2   41973.988
# 11           France        5.9   37675.006
# 12          Germany        7.4   40996.511
# 13           Greece        4.4   18064.288
# 14          Hungary        5.1   12239.894
# 15          Iceland        7.4   50854.583
# 16          Ireland        7.2   51350.744
# 17           Israel        7.4   35343.336
# 18            Italy        5.7   29866.581
# 19            Japan        6.0   32485.545
# 20            Korea        6.1   27195.197
# ...

# %% [markdown]
# Salario!!!
# Argentina
# 13588.84

# %%
money_happiness_df.plot(kind = "scatter", x = "GDP", y = "Happiness")
# Out:
# <Axes: xlabel='GDP', ylabel='Happiness'>

# %%
from sklearn.linear_model import LinearRegression

X = money_happiness_df [["GDP"]]
y = money_happiness_df [["Happiness"]]

# %%
modelo = LinearRegression()
modelo.fit(X , y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
prediction_y = modelo.predict(X)
plt.scatter(X, y,  color='blue')
plt.plot(X,prediction_y, color='red')
plt.show()

# %%
#Argentina 13588.84
# Filtrando o DataFrame para o país "Argentina" fazendo uma predição seria talves: [[5.94150885]]
argentina_gdp = [[13588.84]]

argentina_happiness = modelo.predict(argentina_gdp)
print(argentina_happiness)
# Out:
# [[5.94150885]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Pesquisando o pais Brasil
#money_happiness_df.head(40)

resultado = money_happiness_df[money_happiness_df['Country'] == 'Brazil']
print(resultado)
# Out:
#   Country  Happiness       GDP
# 3  Brazil        6.6  8669.998
