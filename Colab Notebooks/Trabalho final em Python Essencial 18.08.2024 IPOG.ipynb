# %% [markdown]
# **Grupo 06:**
# **Samyr, William Neto e Rodrigo Rodrigues.**
#
# Colab: https://colab.research.google.com/drive/1zpd73C4SIr1q3Q7slEZtjD3qMX2vqqZX#scrollTo=buqWMYZgJE7

# %% [markdown]
# 💻💻**Trabalho final em Python**💻💻
#
# Escreva uma função e dê o nome **limpa_lista_textos. **
#
# Essa função deve **chamar 3 funções nomeadas converte_minusculo, remove_espacos e remove_numeros. **
#
#
# Procure usar List Comprehension quando precisar percorrer a lista.
#
# **Limpem os textos que estão nessa lista de strings usando a função limpa lista textos:**
#
#
# frases = ['Essas frases cont3m palavras que estão inc0rretas e precisam ser el1mind4s',
#           'Bem d3 longe dava para ouvir os gritos da torc;da',
#           'No 38.º disco de sua carreira Elba combina releituras e algumas canc@es inéditas'
# ]

# %%
def converte_minusculo(texto):
    return texto.lower()

def remove_espacos(texto):
    return texto.strip()

def remove_numeros(texto):
    return ''.join([char for char in texto if not char.isdigit()])

def limpa_lista_textos(lista_textos):
    return [
        remove_numeros(
            remove_espacos(
                converte_minusculo(texto)
            )
        )
        for texto in lista_textos

    ]

# %%
frases = ['Essas frases cont3m palavras que estão inc0rretas e precisam ser el1mind4s',
          'Bem d3 longe dava para ouvir os gritos da torc;da',
          'No 38.º disco de sua carreira Elba combina releituras e algumas canc@es inéditas'
]

lista_limpa = limpa_lista_textos(frases)
for texto in lista_limpa:
        print("Lista Limpa: ", texto)
# Out:
# Lista Limpa:  essas frases contm palavras que estão incrretas e precisam ser elminds
# Lista Limpa:  bem d longe dava para ouvir os gritos da torc;da
# Lista Limpa:  no .º disco de sua carreira elba combina releituras e algumas canc@es inéditas

# %% [markdown]
# Otimizando com função para criarmos a lista e depois chamar e depois tratar.

# %%
def criar_lista():
    lista = []
    while True:
        item = input("Informe um item para adicionar à lista (ou digite 'sair' para finalizar): ")
        if item.lower() == 'sair':
            break
        lista.append(item)
    return lista

# %%
lista_limpa = limpa_lista_textos(criar_lista())
for texto in lista_limpa:
        print("Lista Limpa: ", texto)
# Out:
# Informe um item para adicionar à lista (ou digite 'sair' para finalizar): asdasdas
# Informe um item para adicionar à lista (ou digite 'sair' para finalizar): SADASDAS
# Informe um item para adicionar à lista (ou digite 'sair' para finalizar): DASDAS6565656
# Informe um item para adicionar à lista (ou digite 'sair' para finalizar): dds
# Informe um item para adicionar à lista (ou digite 'sair' para finalizar): sair
# Lista Limpa:  ['asdasdas', 'sadasdas', 'dasdas', 'dds']
