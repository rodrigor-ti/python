# %% [markdown]
# **Atividade Prévia Python Essencial**
#
# **Aluno: Rodrigo de Oliveira Rodrigues**

# %% [markdown]
# **Primeiro código Python Essencial**

# %%
print("Hello World")
# Out:
# Hello World
