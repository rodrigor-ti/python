# %% [markdown]
# Pessoal
#
# Por favor, utilizem os dados abaixo:
#
# temperature = [[30],  [12], [14], [18], [25],  [5],  [15], [27]]
#
# coat =        [False, True, True, True, False, True, True, False]
#
# e treinem um modelo Regressão Logística (from sklearn.linear_model import LogisticRegression) capaz de prever se pessoa deve ou não vestir um casaco antes de sair de casa. O objetivo é apenas facilitar o início da primeira aula, uma vez que vocês vão relembrar os conceitos básicos do Google Colab e do Python que usaremos muito durante este o módulo.
#
# É importante que façam essa atividade antes do início do módulo Python em Análise de Dados.
#
# É importante que vocês postem o link compartilhado do Google Colab com a solução do problema apresentado acima como evidência da conclusão desta atividade.
#
# Abraços
#
# professor Seiji

# %% [markdown]
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

temperature = [[30], [12], [14], [18], [25], [5], [15], [27]]
coat = [False, True, True, True, False, True, True, False]

coat = np.array(coat).astype(int)

model = LogisticRegression()
model.fit(temperature, coat)

while True:
    user_input = input("Informe a temperatura em °C (ou digite 'sair' para encerrar): ").strip().lower()

    if user_input == 'sair':
        print("Encerrando o programa. Obrigado!")
        break

    try:
        user_temp = float(user_input)
        test_temp = [[user_temp]]
        prediction = model.predict(test_temp)

        print(f"Com temperatura de {test_temp[0][0]}°C, deve vestir casaco? {'Sim!' if prediction[0] else 'Não!'}")
    except ValueError:
        print("Por favor, insira um valor válido para a temperatura.")
# Out:
# Informe a temperatura em °C (ou digite 'sair' para encerrar): 28,5
# Por favor, insira um valor válido para a temperatura.

# %% [markdown]
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
